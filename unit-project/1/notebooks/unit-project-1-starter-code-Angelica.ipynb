# %% [markdown]
# # DS-SF-36 | Unit Project | 1 | Research Design | Starter Code

# %% [markdown]
# In this first unit project, you will create a framework to scope out data science projects.  This framework will provide you with a guide to develop a well-articulated problem statement and analysis plan that will be robust and reproducible.

# %% [markdown]
# ## Part A.  Evaluate the following problem statement:

# %% [markdown]
# > "Determine which free-tier customers will covert to paying customers, using demographic data collected at signup (age, gender, location, and profession) and customer useage data (days since last log in, and `activity score 1 = active user`, `0 = inactive user`) based on Hooli data from January-April 2015."

# %% [markdown]
# > ### Question 1.  What is the outcome?

# %% [markdown]
# Answer: The outcome is figuring out which free-tier customers will covert to paying customers.

# %% [markdown]
# > ### Question 2.  What are the predictors/covariates?

# %% [markdown]
# Answer: Age, gender, location, profession, days since last log in, activity score (1 = active user, 0 = inactive user)

# %% [markdown]
# > ### Question 3.  What timeframe is this data relevent for?

# %% [markdown]
# Answer: January - April 2015

# %% [markdown]
# > ### Question 4.  What is the hypothesis?

# %% [markdown]
# Answer: Demographic information and customer useage data will allow us to predict which free-tier customers will covert to paying customers.

# %% [markdown]
# ## Part B.  Let's start exploring our UCLA dataset and answer some simple questions:

# %%
import os
import pandas as pd

pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 10)
pd.set_option('display.notebook_repr_html', True)

df = pd.read_csv(os.path.join('..', '..', 'dataset', 'dataset-ucla-admissions.csv'))

df
# Out:
#      admit    gre   gpa  prestige
# 0        0  380.0  3.61       3.0
# 1        1  660.0  3.67       3.0
# 2        1  800.0  4.00       1.0
# 3        1  640.0  3.19       4.0
# 4        0  520.0  2.93       4.0
# ..     ...    ...   ...       ...
# 395      0  620.0  4.00       2.0
# 396      0  560.0  3.04       3.0
# 397      0  460.0  2.63       2.0
# 398      0  700.0  3.65       2.0
# 399      0  600.0  3.89       3.0
#
# [400 rows x 4 columns]

# %% [markdown]
# > ### Question 5.  Create a data dictionary.

# %% [markdown]
# (Use the template below)
#
# Variable | Description | Type of Variable
# ---|---|---
# Var 1 | 0 = Not thing, 1 = Thing | Categorical
# Var 2 | Thing in unit X | Continuous

# %%
#CHECKING TYPE OF VARIABLES IN COLUMNS
#JUST SCRATCH WORK

# admit_type = [type(x) for x in df.admit.mode()]
# gre_type = [type(x) for x in df.gre.mode()]
# gpa_type = [type(x) for x in df.gpa.mode()]
# prest_type = [type(x) for x in df.prestige.mode()]

# %%
#Created a DF for each column I needed in the dictionary
var = pd.DataFrame({"Variable": [x for x in df.columns]})
descr = pd.DataFrame({"Description":["0 = Not admitted, 1 = Admitted","Long Integer(max = 800, min = 0)","Long Integer (max = 4.0, min = 0.0)","1(most prestigious) - 4(less prestigious)"]})
type_var = pd.DataFrame({"Type of Variable": ["Categorical","Continuous","Continuous","Categorical"]})

#First merged 2 columns and created a new df
half_done = var.merge(descr, left_index = True, right_index = True)

#Merged last column with new df
data_dict = half_done.merge(type_var, left_index = True, right_index = True)

data_dict
# Out:
#    Variable                                Description Type of Variable
# 0     admit             0 = Not admitted, 1 = Admitted      Categorical
# 1       gre           Long Integer(max = 800, min = 0)       Continuous
# 2       gpa        Long Integer (max = 4.0, min = 0.0)       Continuous
# 3  prestige  1(most prestigious) - 4(less prestigious)      Categorical

# %% [markdown]
# We would like to explore the association between X and Y.

# %% [markdown]
# > ### Question 6.  What is the outcome?

# %% [markdown]
# Answer: The outcome is to be to identify the various factors that may influence admission into graduate school.

# %% [markdown]
# > ### Question 7.  What are the predictors/covariates?

# %% [markdown]
# Answer: Gre, Gpa, Prestige

# %% [markdown]
# > ### Question 8.  What timeframe is this data relevent for?

# %% [markdown]
# Answer: The data above does not specify a specific timeframe.

# %% [markdown]
# > ### Question 9.  What is the hypothesis?

# %% [markdown]
# Answer: Gre score, GPA, and prestige will allow us to predict which students got admitted into UCLA.

# %% [markdown]
# > ### Question 10.  What's the problem statement?
#
# > Using your answers to the above questions, write a well-formed problem statement.

# %%
import matplotlib.pyplot as plt
df.plot(kind = 'scatter', x = 'gpa', y = 'gre', c = df.admit.map({1: 'red', 0: 'blue'}), s = 100, figsize = (10, 10))

# %% [markdown]
# Answer: From the UCLA data there is not a guarantee that the highest gre, gpa, or prestige of school means the student will be admitted into the graduate school. Each student that was admitted has different qualifications. There were students with a gpa as low as a 2.42 or gre as low as 300 that were still admitted into the graduate school. On the other end of the spectrum, there were students with a perfect gpa and gre score that from prestigious schools not admitted into the graduate school. This becomes problematic for the future students that want to be admitted. There is also not an indicator of what year of admittance this data is from. If a students is looking into this data, but it is from 5+ years ago, the admittance requirements may have changed. Solely off the data we were given does not determine if the student will be admitted, there are other factors that go into the admittance, such as recommendation letters, extracurriculars, etc.  Above I have included a scatter plot of the admitted students(red) versus the non-admitted students(blue). A prospective student might assume that there is a linear relationship that as the gre and gpa increase so does the amount of red, but as seen in the plot there is no definite relationship. Schools should give prospective students recommendations on what to work on when they want to apply for the graduate school because if they focus on gpa and gre that does not mean they will get in.

# %% [markdown]
# ## Part C.  Create an exploratory analysis plan by answering the following questions:

# %% [markdown]
# Because the answers to these questions haven't yet been covered in class yet, this section is <b>optional</b>.  This is by design.  By having you guess or look around for these answers will help make sense once we cover this material in class.  You will not be penalized for wrong answers but we encourage you to give it a try!

# %% [markdown]
# > ### Question 11. What are the goals of the exploratory analysis?

# %% [markdown]
# > ### Question 12.  What are the assumptions of the distribution of data?

# %% [markdown]
# > ### Question 13.  How will determine the distribution of your data?

# %% [markdown]
# > ### Question 14.  How might outliers impact your analysis?

# %% [markdown]
# > ### Question 15.  How will you test for outliers?

# %% [markdown]
# > ### Question 16.  What is colinearity?

# %% [markdown]
# > ### Question 17.  How will you test for covariance?

# %% [markdown]
# > ### Question 18.  What is your exploratory analysis plan?
#
# > Using the above information, write an exploratory analysis plan that would allow you or a colleague to reproduce your analysis one year from now.
