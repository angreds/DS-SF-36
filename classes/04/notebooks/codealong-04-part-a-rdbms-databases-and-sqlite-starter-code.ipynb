# %% [markdown]
# # DS-SF-36 | 04 | Databases and Scrapping | Codealong | Starter Code

# %% [markdown]
# ## Part A | RDBMS Databases and `SQLite`

# %%
import os

import pandas as pd
pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

import sqlite3

# %% [markdown]
# > ### How to connect to a `SQLite` database

# %%
db = sqlite3.connect(os.path.join('..', 'datasets', 'dataset-04-zillow.db'))

# %% [markdown]
# > ### How to use `pandas` to run SQL queries and get the results as a `DataFrame`

# %%
a = ("This is a " +
    "string")

# %%
a = "This is a " +\ 
    "string"
# Out:
# 'This is a string'

# %%
a = """
This is a line
This is another
"""

# %%
a
# Out:
# '\nThis is a line\nThis is another\n'

# %%
pd.io.sql.read_sql(
'''
SELECT p.id, p.size AS size_foo_bar
    FROM properties AS p
    LIMIT 10
;
''', con = db) #this specifies where the connection is (at the top)

# this returns a dataframe
# Out:
#            id  size_foo_bar
# 0  2121978635         557.0
# 1    89239580        1050.0
# 2    15131782         937.0
# 3    15179502        1574.0
# 4    52266124        1205.0
# 5  2100994004         400.0
# 6    15067755         541.0
# 7    15112556        1175.0
# 8    15133321        3094.0
# 9    61288341        1405.0

# %% [markdown]
# ### `SELECT`

# %%
pd.io.sql.read_sql(
'''
SELECT id, sale_price, sale_price_unit
    FROM transactions
;
''', con = db)
# Out:
#             id  sale_price sale_price_unit
# 0     15165953   650000.00               $
# 1     80749447        1.15              $M
# 2     15155751   665000.00               $
# 3     15143887        2.10              $M
# 4     15117639        1.35              $M
# ..         ...         ...             ...
# 995   69819708   731000.00               $
# 996   15076156        5.53              $M
# 997  119685619   625000.00               $
# 998   15113584   895000.00               $
# 999   15068874   650000.00               $
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### `WHERE`

# %%
pd.io.sql.read_sql(
'''
SELECT id, sale_price
    FROM transactions
    WHERE sale_price_unit = '$'
;
''', con = db)
# Out:
#             id  sale_price
# 0     15165953    650000.0
# 1     15155751    665000.0
# 2    124852113    825000.0
# 3     15124281    625000.0
# 4     15071070    718000.0
# ..         ...         ...
# 420  119685503    750000.0
# 421   69819708    731000.0
# 422  119685619    625000.0
# 423   15113584    895000.0
# 424   15068874    650000.0
#
# [425 rows x 2 columns]

# %% [markdown]
# > ### Here's let's convert the unit of `sale_price` from \$ to \$M

# %%
pd.io.sql.read_sql(
'''
SELECT id, sale_price / 1000000 AS sale_price
    FROM transactions
    WHERE sale_price_unit = '$'
;
''', con = db)
# Out:
#             id  sale_price
# 0     15165953       0.650
# 1     15155751       0.665
# 2    124852113       0.825
# 3     15124281       0.625
# 4     15071070       0.718
# ..         ...         ...
# 420  119685503       0.750
# 421   69819708       0.731
# 422  119685619       0.625
# 423   15113584       0.895
# 424   15068874       0.650
#
# [425 rows x 2 columns]

# %% [markdown]
# ### `UNION`

# %% [markdown]
# > ### Let's combine the previous two queries into one.  `sale_price` is now in \$M accross the dataset

# %%
pd.io.sql.read_sql('''
SELECT id, sale_price / 1000000 AS sale_price
    FROM transactions
    WHERE sale_price_unit = '$'
UNION ALL
SELECT id, sale_price
    FROM transactions
    WHERE sale_price_unit = '$M'
;
''', con = db)
# Out:
#              id  sale_price
# 0      15165953       0.650
# 1      15155751       0.665
# 2     124852113       0.825
# 3      15124281       0.625
# 4      15071070       0.718
# ..          ...         ...
# 995  2101028916       2.450
# 996    15091950       1.750
# 997    89237766       1.160
# 998    15197693       1.360
# 999    15076156       5.530
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### `WITH`

# %%
pd.io.sql.read_sql(
'''
WITH normalized_sale_prices AS
    (SELECT id, sale_price / 1000000 AS sale_price
        FROM transactions
        WHERE sale_price_unit = '$'
    UNION ALL
    SELECT id, sale_price
        FROM transactions
        WHERE sale_price_unit = '$M')

SELECT *
    FROM normalized_sale_prices
;
''', con = db)
# Out:
#              id  sale_price
# 0      15165953       0.650
# 1      15155751       0.665
# 2     124852113       0.825
# 3      15124281       0.625
# 4      15071070       0.718
# ..          ...         ...
# 995  2101028916       2.450
# 996    15091950       1.750
# 997    89237766       1.160
# 998    15197693       1.360
# 999    15076156       5.530
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### `JOIN`

# %%
pd.io.sql.read_sql(
'''
WITH normalized_sale_prices AS
    (SELECT id, sale_price / 1000000 AS sale_price
        FROM transactions
        WHERE sale_price_unit = '$'
    UNION ALL
    SELECT id, sale_price
        FROM transactions
        WHERE sale_price_unit = '$M')

SELECT properties.baths AS baths, normalized_sale_prices.sale_price AS sale_price
    FROM properties
    JOIN normalized_sale_prices
        ON normalized_sale_prices.id = properties.id
;
''', con = db)
# Out:
#      baths  sale_price
# 0      1.0       0.650
# 1      2.0       0.665
# 2      NaN       0.825
# 3      1.0       0.625
# 4      1.0       0.718
# ..     ...         ...
# 995    3.0       2.450
# 996    NaN       1.750
# 997    2.5       1.160
# 998    2.0       1.360
# 999    7.5       5.530
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### `WITH` (take 2)

# %%
pd.io.sql.read_sql(
'''
WITH normalized_sale_prices AS
    (SELECT id, sale_price / 1000000 AS sale_price
        FROM transactions
        WHERE sale_price_unit = '$'
    UNION ALL
    SELECT id, sale_price
        FROM transactions
        WHERE sale_price_unit = '$M'),

baths_normalized_sale_prices AS
    (SELECT properties.baths AS baths, normalized_sale_prices.sale_price AS sale_price
        FROM properties
        JOIN normalized_sale_prices
            ON normalized_sale_prices.id = properties.id)

SELECT *
    FROM baths_normalized_sale_prices
;
''', con = db)
# Out:
#      baths  sale_price
# 0      1.0       0.650
# 1      2.0       0.665
# 2      NaN       0.825
# 3      1.0       0.625
# 4      1.0       0.718
# ..     ...         ...
# 995    3.0       2.450
# 996    NaN       1.750
# 997    2.5       1.160
# 998    2.0       1.360
# 999    7.5       5.530
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### `GROUP BY` and `COUNT`

# %% [markdown]
# > ### Let's compute the number of properties based on their number of bedrooms

# %%
pd.io.sql.read_sql(
'''
SELECT COUNT() AS count
    FROM properties
    GROUP BY beds
;
''', con = db)
# Out:
#    count
# 0    164
# 1    142
# 2    316
# 3    226
# 4    103
# 5     28
# 6      9
# 7      6
# 8      3
# 9      3

# %% [markdown]
# ### `GROUP BY` and `AVG`

# %% [markdown]
# > ### Let's now compute the average sale price of these properties based on their number of bathrooms

# %%
pd.io.sql.read_sql(
'''
WITH normalized_sale_prices AS
    (SELECT id, sale_price / 1000000 AS sale_price
        FROM transactions
        WHERE sale_price_unit = '$'
    UNION ALL
    SELECT id, sale_price
        FROM transactions
        WHERE sale_price_unit = '$M'),

baths_normalized_sale_prices AS
    (SELECT properties.baths AS baths, normalized_sale_prices.sale_price AS sale_price
        FROM properties
        JOIN normalized_sale_prices
            ON normalized_sale_prices.id = properties.id)

SELECT baths, AVG(sale_price) AS mean_sale_price
    FROM baths_normalized_sale_prices
    GROUP BY baths
;
''', con = db)
# Out:
#     baths  mean_sale_price
# 0     NaN         1.739026
# 1    1.00         0.987656
# 2    1.10         1.420000
# 3    1.25         1.600000
# 4    1.50         1.223378
# ..    ...              ...
# 16   6.50        16.000000
# 17   7.00         0.999000
# 18   7.50         5.530000
# 19   8.00        13.100000
# 20  14.00         1.000000
#
# [21 rows x 2 columns]

# %% [markdown]
# Note: `baths = 0` usually refers to studios but not always...

# %% [markdown]
# > ### Activity
# > #### Compute the average sales price of studios

# %%
# TODO

pd.io.sql.read_sql(
'''

        
SELECT AVG(t.sale_price)
    FROM properties AS p
    JOIN transactions AS t on p.id = t.id
    WHERE p.is_a_studio =1
    ;
''', con = db)
# Out:
#    AVG(t.sale_price)
# 0      275070.154483

# %% [markdown]
# > ### Activity
# > #### Find the properties in the dataset that have different addresses but the same latitude/longitude.  Return the smallest set of pair of properties (`address_a`, `address_b`)

# %%
pd.io.sql.read_sql(
'''
SELECT a.id, b.id, a.address AS address_a, b.address AS address_b
    FROM properties AS a
    JOIN properties AS b ON b.latitude = a.latitude AND b.longitude = a.longitude
    WHERE a.address > b.address 
;
'''
    , con = db)
# Out:
#            id        id                                        address_a  \
# 0    15076711  15076699  1 Daniel Burnham Ct APT 1404, San Francisco, CA
# 1    15068514  15068551    1177 California St APT 702, San Francisco, CA
# 2    15068514  15068580    1177 California St APT 702, San Francisco, CA
# 3    15068514  15068592    1177 California St APT 702, San Francisco, CA
# 4    80730869  69819664          260 King St UNIT 817, San Francisco, CA
# ..        ...       ...                                              ...
# 102  61288454  60825591             77 Dow Pl APT 507, San Francisco, CA
# 103  15078419  15078423            301 Gough St APT 3, San Francisco, CA
# 104  67395015  63107226    8400 Oceanview Ter APT 218, San Francisco, CA
# 105  67395015  67394898    8400 Oceanview Ter APT 218, San Francisco, CA
# 106  69819412  69819469          250 King St UNIT 410, San Francisco, CA
#
#                                            address_b
# 0    1 Daniel Burnham Ct APT 1202, San Francisco, CA
# 1      1177 California St APT 501, San Francisco, CA
# 2      1177 California St APT 423, San Francisco, CA
# 3      1177 California St APT 304, San Francisco, CA
# 4           260 King St UNIT 1205, San Francisco, CA
# ..                                               ...
# 102             77 Dow Pl APT 500, San Francisco, CA
# 103              301 Gough St # G, San Francisco, CA
# 104     3981 Alemany Blvd APT 206, San Francisco, CA
# 105    8300 Oceanview Ter APT 306, San Francisco, CA
# 106         250 King St UNIT 1304, San Francisco, CA
#
# [107 rows x 4 columns]
