# %% [markdown]
# # DS-SF-36 | 06 | $k$-Nearest Neighbors | Codealong | Starter Code

# %%
import os

import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

from sklearn import preprocessing, neighbors, model_selection

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.read_csv(os.path.join('..', 'datasets', 'dataset-06-iris.csv'))

# %%
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth    Species
# 0            5.1         3.5          1.4         0.2     Setosa
# 1            4.9         3.0          1.4         0.2     Setosa
# 2            4.7         3.2          1.3         0.2     Setosa
# 3            4.6         3.1          1.5         0.2     Setosa
# 4            5.0         3.6          1.4         0.2     Setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  Virginica
# 146          6.3         2.5          5.0         1.9  Virginica
# 147          6.5         3.0          5.2         2.0  Virginica
# 148          6.2         3.4          5.4         2.3  Virginica
# 149          5.9         3.0          5.1         1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Part A | Activity | Iris Dataset | Exploratory Data Analysis

# %%
color = df.Species.map({'Setosa': 'red', 'Versicolor': 'green', 'Virginica': 'blue'})

# %%
df.plot(kind ="scatter", x="PetalWidth", y = "PetalLength", c = color, figsize = (8,8))

# %%
#ANSWER
#the red one is linearably separable bc it's the easiest to distinguish

pd.tools.plotting.scatter_matrix(df[["PetalLength","PetalWidth","SepalLength","SepalWidth"]], c = color, figsize = (16,16))
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:4: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   after removing the cwd from sys.path.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11844e950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1186aae90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1186f5350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118799b50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x118864c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1188d76d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11895d9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1189cf390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x118a55590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118aca110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118b4d690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118b02fd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x118bf02d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118c77190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118cd9fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118d6d310>]], dtype=object)

# %% [markdown]
# ## Part B | Activity | Hand-Coded Classifier

# %%
c = df.Species

# %%
def my_first_classifier(row):
    if row.PetalLength > 5:
        return "Virginica"
    elif row.PetalLength > 2.5:
        return "Versicolor"
    else:
        return "Setosa"

# %%
c_hat = df.apply(my_first_classifier, axis = 1)

c_hat
# Out:
# 0          Setosa
# 1          Setosa
# 2          Setosa
# 3          Setosa
# 4          Setosa
#           ...
# 145     Virginica
# 146    Versicolor
# 147     Virginica
# 148     Virginica
# 149     Virginica
# Length: 150, dtype: object

# %%
(c_hat != c).sum()
# Out:
# 10

# %%
pd.crosstab(c_hat, c, rownames = ['Hypothesized Class'], colnames = ['True Class'])

#everything on the diagonal we are going to call that an accuracy
#everything not on diagonla is a missclassification
# Out:
# True Class          Setosa  Versicolor  Virginica
# Hypothesized Class
# Setosa                  50           0          0
# Versicolor               0          49          9
# Virginica                0           1         41

# %% [markdown]
# ## Part C | Classification Metrics

# %% [markdown]
# ### Accuracy

# %%
# TODO
(c_hat ==c).mean()
# Out:
# 0.93333333333333335

# %% [markdown]
# ### Misclassification rate

# %%
# TODO
(c != c_hat).mean()
# Out:
# 0.066666666666666666

# %% [markdown]
# ## Part D | $k$-Nearest Neighbors ($k$-NN)

# %% [markdown]
# ### Feature matrix and response vector

# %% [markdown]
# - (http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html)

# %%
columns_X = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']
X = df[columns_X]

scaler = preprocessing.MinMaxScaler().fit(X)

X = scaler.transform(X)

# %%
# TODO

# %%
c = df.Species

# %%
c

# %% [markdown]
# ### $k$-Nearest Neighbors

# %% [markdown]
# - (http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html)

# %%
model = neighbors.KNeighborsClassifier(n_neighbors = 1).\
    fit(X, c)

# %% [markdown]
# You can measure the precision of your prediction with `.score()`

# %%
model.score(X, c)

# %%
c_hat = model.predict(X)

# %%
(c_hat == c).mean()

# %%
pd.crosstab(c_hat, c, rownames = ['Hypothesized Class'], colnames = ['True Class'])

# %% [markdown]
# ### Train/test sets

# %% [markdown]
# - (http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sample.html)

# %% [markdown]
# 50% of the dataset to train the model; the rest to test the model

# %%
train_df = df.sample(frac = .5, random_state = 0).sort_index()

# %%
train_df

# %%
test_df = df.drop(train_df.index)

# %% [markdown]
# ### Feature matrix `train_X` and response vector `train_c`

# %%
train_X = train_df[columns_X]

scaler = preprocessing.MinMaxScaler().fit(train_X)
train_X = scaler.transform(train_X)

train_c = train_df.Species

# %% [markdown]
# ### Feature matrix `test_X` and response vector `test_c`

# %% [markdown]
# - (http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html)
# - (http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html)

# %%
# TODO

# %%
k_cv = 5 # 5-fold CV
k_nn = range(1, train_df.shape[0] * (k_cv - 1) / k_cv) # k-NN

gs = model_selection.GridSearchCV(
    estimator = neighbors.KNeighborsClassifier(),
    param_grid = {'n_neighbors': k_nn, 'weights': ['uniform', 'distance']},
    cv = model_selection.KFold(n_splits = k_cv, shuffle = True, random_state = 0)
)

gs.fit(train_X, train_c)

# %%
gs.cv_results_

# %%
gs.cv_results_.keys()

# %%
gs.best_score_

# %%
gs.best_params_

# %%
gs.best_estimator_

# %%
gs.score(train_X, train_c)

# %%
gs.score(test_X, test_c)

# %% [markdown]
# ## Final model

# %%
# TODO
